# %%
import numpy as np
import pandas as pd
#import torch
#import torch.nn.functional as F
#import tensorflow as tf
#from tensorflow import keras
import warnings
warnings.filterwarnings('ignore')

# %%
#import torch
#from torch.autograd import Variable
#import torch.nn.functional as F
#import torch.utils.data as Data

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
# import imageio

# %% [markdown]
# # Bayesian

# %%
def f(x):
    val = 2*x[0]**2 +x[1]
    return val

# %%
#defining the objective function 

def objective(X, target):
    
#     X = torch.tensor(X).float()
#     X = X.cuda()
#     res = net(X) - target
 
    res = abs(f(X) - target)
    #return f,net(x),target
    return res 


X_init = [0,1]
Y_init = f(X_init)
target = 11

# %%
res_1 = objective(X_init , target)

# %%
#defining a random dummy hidden constraint function. 

epsilon = 0.05
def hidden(X):
    
    if objective(X, target) < epsilon and objective(X, target) > -epsilon :    #error aloowed
        print('\nsuccess bcoz {}'.format(objective(X, target)))
        return -1   #success
    else:
        print('\nfailure bcoz {}'.format(objective(X, target)))
        return 1    #failure

# %%
from scipy.stats import norm

def expected_improvement(X, X_sample, Y_sample, gpr, gpr_h, xi=0.01):
    '''
    Computes the EI at points X based on existing samples X_sample
    and Y_sample using a Gaussian process surrogate model.
    
    Args:
        X: Points at which EI shall be computed (m x d).
        X_sample: Sample locations (n x d).
        Y_sample: Sample values (n x 1).
        gpr: A GaussianProcessRegressor fitted to samples.
        xi: Exploitation-exploration trade-off parameter.
        **kwargs: GPR for modelling the hidden constraint values (arg name : 'gpr_h')
    
    Returns:
        Expected improvements at points X.
    '''
    mu, sigma = gpr.predict(X, return_std=True)
    mu_sample = gpr.predict(X_sample)

    sigma = sigma.reshape(-1, 1)
    
    # Needed for noise-based model,
    # otherwise use np.max(Y_sample).
    # See also section 2.4 in [...]
    mu_sample_opt = np.max(mu_sample)

    #Computing the posterior mean and var for the hidden constraint
    mu_h, sigma_h = gpr_h.predict(X, return_std=True)

    sigma_h = sigma_h.reshape(-1, 1)


    with np.errstate(divide='warn'):
        imp = mu - mu_sample_opt - xi
        Z = imp / sigma
        ei = imp * norm.cdf(Z) + sigma * norm.pdf(Z)
        ei[sigma == 0.0] = 0.0
             
        #Compting new acquisition function
        ei = ei * norm.cdf(-mu_h/sigma_h)

        
    return ei

# %%
from scipy.optimize import minimize

def propose_location(acquisition, X_sample, Y_sample, gpr, gpr_h, bounds, n_restarts=25):
    '''
    Proposes the next sampling point by optimizing the acquisition function.
    
    Args:
        acquisition: Acquisition function.
        X_sample: Sample locations (n x d).
        Y_sample: Sample values (n x 1).
        gpr: A GaussianProcessRegressor fitted to samples.

    Returns:
        Location of the acquisition function maximum.
    '''
    dim = X_sample.shape[1]
    min_val = 1
    min_x = None
    
    def min_obj(X):
        # Minimization objective is the negative acquisition function
        return -acquisition(X.reshape(-1, dim), X_sample, Y_sample, gpr, gpr_h)
    
#     print(np.random.uniform(bounds[:, 0], bounds[:, 1], size=(n_restarts, dim)))
    
    # Find the best optimum by starting from n_restart different random points.
    
    for x0 in np.random.uniform(bounds[:, 0], bounds[:,1],size=(n_restarts, dim)):
        
        #print(len(x0))
        res = minimize(min_obj, x0=x0, bounds=bounds, method='L-BFGS-B')        
        if res.fun < min_val:
            min_val = res.fun[0]
            min_x = res.x           
            
    return min_x.reshape(-1, 1)

# %%
import numpy as np

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ConstantKernel, Matern

# %%
def bayes_opt(model,x_init, y, h, bounds, n_iter = 100):
    '''
    model : the output from the neural network 
    x (list):the first 8 variables whose values are fixed
    y (list): the target value 
    bounds (list of list): lower and upper bounds of the variables whose values are to be determined 
    '''
    res_1 = y[0]
    
    #model.eval()

    # Gaussian process with Matérn kernel as surrogate model
    m52 = ConstantKernel(1.0) * Matern(length_scale=1.0, nu=2.5)
    gpr = GaussianProcessRegressor(kernel=m52)
    gpr_h = GaussianProcessRegressor(kernel=m52)

    # Initialize samples
    x_sample = np.array(x_init).reshape(1, -1)
    y_sample = np.array(y)
    h_sample = np.array(h)
    

    for i in range(n_iter):
        # Update Gaussian process with existing samples
        gpr.fit(x_sample, y_sample)
        gpr_h.fit(x_sample, h_sample)

        # Obtain next sampling point from the acquisition function (expected_improvement)
        x_next = propose_location(expected_improvement, x_sample, y_sample, gpr, gpr_h, bounds)
        x_next = x_next.reshape(1,-1)
        x_next = list(x_next[0])
        x = x_next
        #x.extend(x_next)                        this commented out part was for the case where the first few x_i in
#                                                a_1x_1+a2x_2 +...... = y was fixed.


        # Obtain next noisy sample from the objective function
        y_next = objective(x, target)
        y_next = y_next.tolist()
        
        # Obtain next hidden constraint 
        h_next = hidden(x)
        #h_next = h_next.tolist()
        
        # Add sample to previous samples
        x_sample = np.vstack((x_sample, x_next))
        y_sample = np.vstack((y_sample, y_next))
        h_sample = np.vstack((h_sample, h_next))
        
        print('New sampled input : {}, observed output {}, constraint {}'.format(x_next, y_next, h_next))
        tolerance = 0.05
        change = np.linalg.norm(x_sample[len(x_sample)-1]-x_sample[len(x_sample)-2],2 )
        #print(change)
        
        
        if change < tolerance:            
            break
#         if i != n_iter-1:                      this commented out part was for the case where the first few x_i in
#                                                a_1x_1+a2x_2 +...... = y was fixed.

#             x = x[:-3]
                

        print('\nAfter {} iterations, minimum objective value achieved {}'.format(i, np.min(y_sample)))
        print('\nOptimal input {}'.format(x_sample[np.argmin(y_sample)]))
   
    
    return x_sample[np.argmin(y_sample)]

# %%
x_init = [0,1]
y_init = [f(x_init)]
h_init = [1]

# on changing the number of variables it will automatically detect from the dimension of the bounds
limits = np.array([[0,10],[0,10]])

# %%
output = bayes_opt(f, x_init, y_init, h_init, limits, 100)
# Out:
# failure bcoz 7.491006691796452
# New sampled input : [0.7750102465514919, 2.30771154368394], observed output 7.491006691796452, constraint 1
#
# After 0 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 57.56999884101444
# New sampled input : [5.449185921222313, 9.182744432919506], observed output 57.56999884101444, constraint 1
#
# After 1 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 130.3645259869826
# New sampled input : [8.342491372677541, 2.1702013805842046], observed output 130.3645259869826, constraint 1
#
# After 2 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 47.95971611973279
# New sampled input : [5.1809160068718265, 5.27593477921137], observed output 47.95971611973279, constraint 1
#
# After 3 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 8.064675333611822
# New sampled input : [0.8470336460947248, 1.5003926711551308], observed output 8.064675333611822, constraint 1
#
# After 4 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 106.02644925188325
# New sampled input : [7.648686767055054, 0.021630730837081114], observed output 106.02644925188325, constraint 1
#
# After 5 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 9.16240244127425
# New sampled input : [3.153968865074339, 0.26736323755761626], observed output 9.16240244127425, constraint 1
#
# After 6 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 190.56128735375862
# New sampled input : [9.999595559142458, 1.5774646609154885], observed output 190.56128735375862, constraint 1
#
# After 7 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 26.682085909987883
# New sampled input : [3.9908326743024105, 5.828595041428423], observed output 26.682085909987883, constraint 1
#
# After 8 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 68.61527059727985
# New sampled input : [6.124773594167509, 4.589567437656671], observed output 68.61527059727985, constraint 1
#
# After 9 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 160.92429501264425
# New sampled input : [9.154099751469285, 4.329210492944173], observed output 160.92429501264425, constraint 1
#
# After 10 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 109.97864323588158
# New sampled input : [7.650336831716147, 3.9233359584562812], observed output 109.97864323588158, constraint 1
#
# After 11 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 52.68225495120598
# New sampled input : [5.282560144762868, 7.871371585131801], observed output 52.68225495120598, constraint 1
#
# After 12 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 69.64128193531883
# New sampled input : [6.3054099947795645, 1.1248915307867746], observed output 69.64128193531883, constraint 1
#
# After 13 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 50.568627427797836
# New sampled input : [5.228795909948552, 6.888014092008423], observed output 50.568627427797836, constraint 1
#
# After 14 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 94.36114153158059
# New sampled input : [6.91183861086242, 9.8141155663635], observed output 94.36114153158059, constraint 1
#
# After 15 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 112.78333276797615
# New sampled input : [7.83321253267877, 1.06489560374464], observed output 112.78333276797615, constraint 1
#
# After 16 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 35.44545699193687
# New sampled input : [4.301431041281268, 9.440838986140763], observed output 35.44545699193687, constraint 1
#
# After 17 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 122.58323466829805
# New sampled input : [8.047166839598429, 4.069446379632917], observed output 122.58323466829805, constraint 1
#
# After 18 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 92.38282269051312
# New sampled input : [7.141047305858872, 1.3937094414846218], observed output 92.38282269051312, constraint 1
#
# After 19 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 140.17944057938004
# New sampled input : [8.66834625738444, 0.898986903558382], observed output 140.17944057938004, constraint 1
#
# After 20 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 6.283413246548034
# New sampled input : [0.43635001504885973, 4.335784082185686], observed output 6.283413246548034, constraint 1
#
# After 21 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 4.252612983654222
# New sampled input : [1.4904902112796647, 2.304264876504779], observed output 4.252612983654222, constraint 1
#
# After 22 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 8.896819364580303
# New sampled input : [0.2649231407982444, 1.9628120943588834], observed output 8.896819364580303, constraint 1
#
# After 23 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 89.72444083071667
# New sampled input : [6.987771323522516, 3.0665446910294536], observed output 89.72444083071667, constraint 1
#
# After 24 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 5.8924232935644625
# New sampled input : [2.5291025913027387, 4.099703458896007], observed output 5.8924232935644625, constraint 1
#
# After 25 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 58.65148638860761
# New sampled input : [5.861203696090698, 0.9440688544730991], observed output 58.65148638860761, constraint 1
#
# After 26 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 134.25420085069177
# New sampled input : [8.25676340609169, 8.905916962342117], observed output 134.25420085069177, constraint 1
#
# After 27 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 72.88178149311594
# New sampled input : [6.264928088867199, 5.3831335757615], observed output 72.88178149311594, constraint 1
#
# After 28 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 151.31824971817963
# New sampled input : [9.004028911955102, 0.173176423532877], observed output 151.31824971817963, constraint 1
#
# After 29 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 37.62384560959755
# New sampled input : [4.859937229020337, 1.3858658695618042], observed output 37.62384560959755, constraint 1
#
# After 30 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 7.3400925748792964
# New sampled input : [2.429026184226557, 6.5397561675628415], observed output 7.3400925748792964, constraint 1
#
# After 31 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 4.7007205259178555
# New sampled input : [1.1772710314329293, 3.527345311179838], observed output 4.7007205259178555, constraint 1
#
# After 32 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 2.4118403938330992
# New sampled input : [1.865046622199309, 1.6313618002127972], observed output 2.4118403938330992, constraint 1
#
# After 33 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 95.1625123724809
# New sampled input : [7.263347394501917, 0.6500816260453335], observed output 95.1625123724809, constraint 1
#
# After 34 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 2.9506937949546987
# New sampled input : [0.10685921808496257, 8.026468420065843], observed output 2.9506937949546987, constraint 1
#
# After 35 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 10.70976372180845
# New sampled input : [2.5844795701586842, 8.350694424673215], observed output 10.70976372180845, constraint 1
#
# After 36 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 10.258419368689836
# New sampled input : [3.2491623244639776, 0.1443077472575216], observed output 10.258419368689836, constraint 1
#
# After 37 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 8.993682293703154
# New sampled input : [0.9516845162337506, 0.19491086941871072], observed output 8.993682293703154, constraint 1
#
# After 38 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 59.76934164481828
# New sampled input : [5.562798746886116, 8.879881848102793], observed output 59.76934164481828, constraint 1
#
# After 39 iterations, minimum objective value achieved 1.0
#
# Optimal input [0. 1.]
#
# failure bcoz 0.08960348581841515
# New sampled input : [1.1503340198626555, 8.263859799674833], observed output 0.08960348581841515, constraint 1
#
# After 40 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 166.86554986795443
# New sampled input : [9.171154766650977, 9.645390360224551], observed output 166.86554986795443, constraint 1
#
# After 41 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 8.653644581798009
# New sampled input : [0.08915012646156684, 2.330459928105765], observed output 8.653644581798009, constraint 1
#
# After 42 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 0.3857117610824492
# New sampled input : [1.6233171637165145, 5.343971010884292], observed output 0.3857117610824492, constraint 1
#
# After 43 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 53.49081918590855
# New sampled input : [5.670711837866074, 0.17687368967970074], observed output 53.49081918590855, constraint 1
#
# After 44 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 43.519404141143625
# New sampled input : [5.074730026452714, 3.0136344583820893], observed output 43.519404141143625, constraint 1
#
# After 45 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 1.7190442153047947
# New sampled input : [1.595687462236982, 7.626607261024193], observed output 1.7190442153047947, constraint 1
#
# After 46 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 4.44787513890002
# New sampled input : [2.4077692182406496, 3.853169922285642], observed output 4.44787513890002, constraint 1
#
# After 47 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 15.360456552009925
# New sampled input : [3.6120865879720943, 0.26611751399415295], observed output 15.360456552009925, constraint 1
#
# After 48 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 102.70276874532914
# New sampled input : [7.436403878992655, 3.102563442335129], observed output 102.70276874532914, constraint 1
#
# After 49 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 32.0689579818626
# New sampled input : [4.314298020723877, 5.84262315861868], observed output 32.0689579818626, constraint 1
#
# After 50 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 26.263430993898865
# New sampled input : [3.8526077371985057, 7.578258240455287], observed output 26.263430993898865, constraint 1
#
# After 51 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 3.7834804610755404
# New sampled input : [0.025789785098562223, 7.2151893128935995], observed output 3.7834804610755404, constraint 1
#
# After 52 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 155.19917577248182
# New sampled input : [8.8521694355328, 9.47736834171968], observed output 155.19917577248182, constraint 1
#
# After 53 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 196.48294667360815
# New sampled input : [9.953647067387877, 9.332766789369604], observed output 196.48294667360815, constraint 1
#
# After 54 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 6.879868605427853
# New sampled input : [1.3690904217336308, 0.37131422880660514], observed output 6.879868605427853, constraint 1
#
# After 55 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 8.678011943689711
# New sampled input : [3.1006762222744366, 0.4496258729335656], observed output 8.678011943689711, constraint 1
#
# After 56 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 127.9150281283413
# New sampled input : [8.328258043500117, 0.19526405009250403], observed output 127.9150281283413, constraint 1
#
# After 57 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 0.5369372287665701
# New sampled input : [0.6450104182497718, 9.630985891931939], observed output 0.5369372287665701, constraint 1
#
# After 58 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 5.277742908004377
# New sampled input : [2.171059337038023, 6.850745618124417], observed output 5.277742908004377, constraint 1
#
# After 59 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 102.91459240894929
# New sampled input : [7.425578936868761, 3.636147313611292], observed output 102.91459240894929, constraint 1
#
# After 60 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 82.84714255894329
# New sampled input : [6.792712806946827, 1.5652480036243854], observed output 82.84714255894329, constraint 1
#
# After 61 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 9.32413117990623
# New sampled input : [0.22124177512464538, 1.5779729739731618], observed output 9.32413117990623, constraint 1
#
# After 62 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 5.121778103166662
# New sampled input : [1.9277494939435336, 8.689341880367563], observed output 5.121778103166662, constraint 1
#
# After 63 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 117.45778849669733
# New sampled input : [7.864389226401091, 4.760552688030223], observed output 117.45778849669733, constraint 1
#
# After 64 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 1.9155008229484736
# New sampled input : [0.4151540406073584, 8.739793422186294], observed output 1.9155008229484736, constraint 1
#
# After 65 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 26.811514521413784
# New sampled input : [3.9425898335006537, 6.723485330968362], observed output 26.811514521413784, constraint 1
#
# After 66 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 71.79032376262211
# New sampled input : [6.11692737533827, 7.9567227322966225], observed output 71.79032376262211, constraint 1
#
# After 67 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 13.379926219385084
# New sampled input : [3.050616292437256, 5.7674066920178255], observed output 13.379926219385084, constraint 1
#
# After 68 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 8.853093261214507
# New sampled input : [0.7583281246776008, 0.9967836494313997], observed output 8.853093261214507, constraint 1
#
# After 69 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 1.9555021868722164
# New sampled input : [2.3343118855623732, 2.0574782287166906], observed output 1.9555021868722164, constraint 1
#
# After 70 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 93.90022331509815
# New sampled input : [7.190017037946892, 1.5075333031649518], observed output 93.90022331509815, constraint 1
#
# After 71 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 127.21392976231368
# New sampled input : [8.12718651395636, 6.111608497045408], observed output 127.21392976231368, constraint 1
#
# After 72 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 171.0025843674652
# New sampled input : [9.50602823715455, 1.273438676305888], observed output 171.0025843674652, constraint 1
#
# After 73 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 97.77626052344795
# New sampled input : [7.155709882418771, 6.367892680756632], observed output 97.77626052344795, constraint 1
#
# After 74 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 189.6512446755045
# New sampled input : [9.785944529938433, 9.121823989440594], observed output 189.6512446755045, constraint 1
#
# After 75 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 1.9123882687365459
# New sampled input : [1.5625931462384057, 8.028993587394066], observed output 1.9123882687365459, constraint 1
#
# After 76 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 128.02708900859093
# New sampled input : [8.165082250119976, 5.689952706142353], observed output 128.02708900859093, constraint 1
#
# After 77 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 128.94997198240335
# New sampled input : [8.334008239130831, 1.0385853226021757], observed output 128.94997198240335, constraint 1
#
# After 78 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 168.35649955370303
# New sampled input : [9.370256158001114, 3.7530986205874384], observed output 168.35649955370303, constraint 1
#
# After 79 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 12.060806944479836
# New sampled input : [3.10971833437533, 3.7201107061796823], observed output 12.060806944479836, constraint 1
#
# After 80 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 62.741080445475745
# New sampled input : [5.761173666321344, 7.358836418446721], observed output 62.741080445475745, constraint 1
#
# After 81 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 175.68861163769694
# New sampled input : [9.651227217050952, 0.39623804740683943], observed output 175.68861163769694, constraint 1
#
# After 82 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 137.11437737213743
# New sampled input : [8.399273899851243, 7.018773282692797], observed output 137.11437737213743, constraint 1
#
# After 83 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 87.96469128304412
# New sampled input : [6.9277680412029055, 2.9767512176194444], observed output 87.96469128304412, constraint 1
#
# After 84 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 175.98642779020932
# New sampled input : [9.496298225401036, 6.6270678186995955], observed output 175.98642779020932, constraint 1
#
# After 85 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 105.13120397630334
# New sampled input : [7.498993130951799, 3.6614080201787913], observed output 105.13120397630334, constraint 1
#
# After 86 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 119.09165976398327
# New sampled input : [7.990627642892598, 2.3913995092646454], observed output 119.09165976398327, constraint 1
#
# After 87 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 1.3588504370336416
# New sampled input : [0.31288056462346003, 9.445361067528168], observed output 1.3588504370336416, constraint 1
#
# After 88 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 7.176877274234376
# New sampled input : [0.5056024639009871, 3.311855022760126], observed output 7.176877274234376, constraint 1
#
# After 89 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 7.744729390017693
# New sampled input : [0.6739169756823693, 2.3469424297565644], observed output 7.744729390017693, constraint 1
#
# After 90 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 106.47075804158975
# New sampled input : [7.363537969262514, 9.027375192048334], observed output 106.47075804158975, constraint 1
#
# After 91 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 117.05371182520093
# New sampled input : [7.950283937196993, 1.6396824610958904], observed output 117.05371182520093, constraint 1
#
# After 92 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 115.50710135437767
# New sampled input : [7.741380552593914, 6.649155634219156], observed output 115.50710135437767, constraint 1
#
# After 93 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 126.59342448505453
# New sampled input : [8.276559822846576, 0.5905394827382504], observed output 126.59342448505453, constraint 1
#
# After 94 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 116.06141547767835
# New sampled input : [7.855815322234786, 3.633746723560678], observed output 116.06141547767835, constraint 1
#
# After 95 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 6.241492755733724
# New sampled input : [1.1501864832372866, 2.112649351822763], observed output 6.241492755733724, constraint 1
#
# After 96 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 189.99278856390512
# New sampled input : [9.871287620648276, 6.108149984777292], observed output 189.99278856390512, constraint 1
#
# After 97 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 52.189492473110725
# New sampled input : [5.355514754478018, 5.826415902247234], observed output 52.189492473110725, constraint 1
#
# After 98 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]
#
# failure bcoz 19.722083311334845
# New sampled input : [3.311220605215246, 8.793719518530807], observed output 19.722083311334845, constraint 1
#
# After 99 iterations, minimum objective value achieved 0.08960348581841515
#
# Optimal input [1.15033402 8.2638598 ]

# %%
output
# Out:
# array([1.15033402, 8.2638598 ])

# %%
f(output)
# Out:
# 10.910396514181585
